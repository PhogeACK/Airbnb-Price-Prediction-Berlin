# %%
import pandas as pd
import warnings
from sklearn.model_selection import train_test_split

# Ignore warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle(r'\\popnasal07.bnhpgroup.com\Departments\DIGITALFACTORY\GENERAL\קורס DS - AIRBNB\f_selection.pkl')

# %%
df
# Out:
#        Listing ID  Host Response Rate  Accomodates  Price  Guests Included  \
# 0            2695                 0.5          2.0   17.0              1.0
# 1            3176                 0.5          4.0   90.0              2.0
# 2            7071                 1.0          2.0   33.0              1.0
# 3            9991                 1.0          7.0  180.0              5.0
# 4           14325                 1.0          1.0   70.0              1.0
# ...           ...                 ...          ...    ...              ...
# 12212    31144871                 1.0          2.0   25.0              1.0
# 12213    31161939                 0.9          2.0   25.0              1.0
# 12214    31171455                 1.0          4.0  110.0              2.0
# 12215    31185236                 1.0          1.0   40.0              1.0
# 12216    31206380                 1.0          2.0   25.0              1.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12217 entries, 0 to 12216
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Listing ID                    12217 non-null  int64
#  1   Host Response Rate            12217 non-null  float64
#  2   Accomodates                   12217 non-null  float64
#  3   Price                         12217 non-null  float64
#  4   Guests Included               12217 non-null  float64
#  5   Min Nights                    12217 non-null  float64
#  6   Reviews                       12217 non-null  float64
#  7   Overall Rating                12217 non-null  float64
#  8   review_mnt                    12217 non-null  Float64
#  9   Host_tenure                   12217 non-null  float64
#  10  Is Superhost                  12217 non-null  bool
#  11  Instant Bookable              12217 non-null  bool
# ...

# %%
df.describe()
# Out:
#          Listing ID  Host Response Rate   Accomodates         Price  \
# count  1.221700e+04        12217.000000  12217.000000  12217.000000
# mean   1.718802e+07            0.672573      2.802570     63.583343
# std    8.909828e+06            0.442070      1.658554     51.099375
# min    2.695000e+03            0.000000      1.000000      0.000000
# 25%    9.994644e+06            0.000000      2.000000     35.000000
# 50%    1.932406e+07            1.000000      2.000000     50.000000
# 75%    2.421972e+07            1.000000      4.000000     75.000000
# max    3.120638e+07            1.000000     16.000000    888.000000
#
#        Guests Included    Min Nights       Reviews  Overall Rating  \
# count     12217.000000  12217.000000  12217.000000    12217.000000
# mean          1.427355      6.117214   1147.741671       94.990621
# std           0.948656     22.151903   3466.926273        5.999486
# min           1.000000      1.000000      1.000000       20.000000
# ...

# %%
df.isna().sum()
# Out:
# Listing ID                      0
# Host Response Rate              0
# Accomodates                     0
# Price                           0
# Guests Included                 0
# Min Nights                      0
# Reviews                         0
# Overall Rating                  0
# review_mnt                      0
# Host_tenure                     0
# Is Superhost                    0
# Instant Bookable                0
# Total Bookings                  0
# Sentiment_All                   0
# Sentiment_Nut_per               0
# Sentiment_Pos_per               0
# Cleanliness Rating_encoded      0
# Communication Rating_encoded    0
# Neighborhood Group_encoded      0
# Location Rating_encoded         0
# Value Rating_encoded            0
# Bathrooms_encoded               0
# Bedrooms_encoded                0
# Beds_encoded                    0
# Host Response Time_encoded      0
# Property Type_encoded           0
# Room Type_encoded               0
# dtype: int64

# %% [markdown]
# # Metrics

# %%
models_list = pd.DataFrame()

# %%
def regressionMetrics(y, yhat):
    # Ensure no zero or negative values for MSLE
    epsilon = 1e-6  # Small constant to avoid zero or negative values
    y_safe = np.maximum(y, epsilon)  # Replace non-positive values with epsilon
    yhat_safe = np.maximum(yhat, epsilon)  # Same for predictions
# Calculate the metrics
    res = {
        'MSE': metrics.mean_squared_error(y, yhat),
        'RMSE': np.sqrt(metrics.mean_squared_error(y, yhat)),
        'MAE': metrics.mean_absolute_error(y, yhat),
        'RMSLE': np.sqrt(metrics.mean_squared_log_error(y_safe, yhat_safe))  # Comma was missing here
            }
    return res

# %%
X = df.loc[:,df.columns != 'Price']
y = df['Price']

# Split into train+val and test sets (85% train+val, 15% test)
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.15, random_state=862
)

#80% train+val
# Split train+val into train and val sets (75% train, 25% val from the train+val set)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.176471, random_state=862
)

# %% [markdown]
# ## Regression Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBClassifier, XGBRegressor, DMatrix, train
import sys
import xgboost as xgb
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn.metrics as metrics 
import math
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
models_list = pd.DataFrame()

# %% [markdown]
# ### Linear Regression

# %%
mod1 = LinearRegression()
mod1.fit(X_train, y_train) # Use X_train and y_train

# Make predictions on the validation set
pred1 = mod1.predict(X_val)

# %%
regressionMetrics(y_val, pred1)
# Out:
# {'MSE': 1316.639827375931,
#  'RMSE': 36.285531929075134,
#  'MAE': 20.66939747191263,
#  'RMSLE': 0.44340500591509485}

# %%
model_dict = {'model': "Linear Regression"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_val, pred1)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405

# %%
sns.scatterplot(x=y_val, y=pred1)
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mod2 = DecisionTreeRegressor(random_state=1, min_samples_leaf=5)
mod2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(min_samples_leaf=5, random_state=1)

# %%
# Make predictions on the validation set
pred2 = mod2.predict(X_val)

# %%
model_dict = {'model': "Decision Tree"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_val, pred2)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893

# %%
sns.scatterplot(x=y_val, y=pred2)
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# ### Random Forest

# %%
mod3 = RandomForestRegressor(random_state=1, min_samples_leaf=3)
mod3.fit(X_train, y_train)
# Out:
# RandomForestRegressor(min_samples_leaf=3, random_state=1)

# %%
# Make predictions on the validation set
pred3 = mod3.predict(X_val)


from sklearn.metrics import r2_score 
# Calculate R-squared using the actual and predicted values
r_squared = r2_score(y_val, pred3)
r_squared
# Out:
# 0.5666059504834782

# %%
model_dict = {'model': "RandomForest"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_val, pred3)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448

# %%
sns.scatterplot(x=y_val, y=pred3)
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# ### Adaptive Boosting (ADABoost)

# %%
mod4 = AdaBoostRegressor(random_state=1)
mod4.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(random_state=1)

# %%
pred4 = mod4.predict(X_val)
model_dict = {'model': "ADABoost"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_val, pred4)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123

# %%
sns.scatterplot(x=y_val, y=pred4)
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# ### Gradient Boosting Machine (GBM)

# %%
mod5 = GradientBoostingRegressor(random_state=1)
mod5.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=1)

# %%
pred5 = mod5.predict(X_val)
model_dict = {'model': "GBM"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_val, pred5)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123
# 4                GBM  1262.956631  35.538101  19.381132  0.398192

# %%
sns.scatterplot(y=y_val, x=pred5)
# Out:
# <Axes: ylabel='Price'>

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
mod6 = SVR()
mod6.fit(X_train, y_train)
# Out:
# SVR()

# %%
pred6 = mod6.predict(X_val)
model_dict = {'model': "SVM"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_val, pred6)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123
# 4                GBM  1262.956631  35.538101  19.381132  0.398192
# 5                SVM  2780.709857  52.732436  29.119132  0.582994

# %%
sns.scatterplot(y=y_val, x=pred6)
# Out:
# <Axes: ylabel='Price'>

# %% [markdown]
# # XGBoost Regressor

# %%
mod7= xgb.XGBRegressor()
mod7.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred7 = mod7.predict(X_val)
model_dict = {'model': "XGB"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_val, pred7)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123
# 4                GBM  1262.956631  35.538101  19.381132  0.398192
# 5                SVM  2780.709857  52.732436  29.119132  0.582994
# 6                XGB  1250.342624  35.360184  19.934412  0.405870

# %%
sns.scatterplot(y=y_val, x=pred6)
# Out:
# <Axes: ylabel='Price'>

# %% [markdown]
# ## Model Selection

# %%
models_list.sort_values('MAE')
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 4                GBM  1262.956631  35.538101  19.381132  0.398192
# 6                XGB  1250.342624  35.360184  19.934412  0.405870
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 5                SVM  2780.709857  52.732436  29.119132  0.582994
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123

# %%
models_list.sort_values('RMSE')
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 6                XGB  1250.342624  35.360184  19.934412  0.405870
# 4                GBM  1262.956631  35.538101  19.381132  0.398192
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123
# 5                SVM  2780.709857  52.732436  29.119132  0.582994

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid to search
param_grid = {
    'n_estimators': [10, 50, 100, 200],  # Number of trees in the forest
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider at every split
    'max_depth': [None, 10, 20, 30, 40, 50],  # Maximum number of levels in tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4],  # Minimum number of samples required at each leaf node
}

# Create a base model
rf = RandomForestRegressor()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, 
                           cv=3, n_jobs=-1, verbose=2)
#Verbose - level of details that will be provided in each iteration
# Fit the grid search to the data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30, 40, 50],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 200]},
#              verbose=2)

# %%
# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", -grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best Score: -0.5119561829217767

# %% [markdown]
# # Best model Finetuning

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'max_features': [None, 'sqrt', 'log2'],
    'criterion': ['mse', 'friedman_mse', 'mae']
}

# Initialize the model
mod2 = DecisionTreeRegressor(random_state=1)

# Set up GridSearchCV
grid_search = GridSearchCV(estimator=mod2, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2, scoring='neg_mean_squared_error')

# Fit the model
grid_search.fit(X_test, y_test)

# Print the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score (MSE):", -grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 324 candidates, totalling 972 fits
# Best Parameters: {'criterion': 'friedman_mse', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# Best Score (MSE): 1727.915259205254

# %%
print("Best Score (RMSLE):", -grid_search.best_score_)
# Out:
# Best Score (RMSLE): 1727.915259205254

# %%
pred8 = grid_search.predict(X_test)
model_dict = {'model': "RandomForest_FT"}
new_row = pd.DataFrame([{**model_dict, **regressionMetrics(y_test, pred8)}])
models_list = pd.concat([models_list, new_row], ignore_index=True)
models_list
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123
# 4                GBM  1262.956631  35.538101  19.381132  0.398192
# 5                SVM  2780.709857  52.732436  29.119132  0.582994
# 6                XGB  1250.342624  35.360184  19.934412  0.405870
# 7    RandomForest_FT  1191.343225  34.515840  20.939623  0.398375

# %%
models_list.sort_values('MAE')
# Out:
#                model          MSE       RMSE        MAE     RMSLE
# 2       RandomForest  1135.687989  33.699970  19.056473  0.385448
# 4                GBM  1262.956631  35.538101  19.381132  0.398192
# 6                XGB  1250.342624  35.360184  19.934412  0.405870
# 0  Linear Regression  1316.639827  36.285532  20.669397  0.443405
# 7    RandomForest_FT  1191.343225  34.515840  20.939623  0.398375
# 1      Decision Tree  1549.950824  39.369415  23.232589  0.457893
# 5                SVM  2780.709857  52.732436  29.119132  0.582994
# 3           ADABoost  2337.537473  48.348087  38.195332  0.706123

# %%
import matplotlib.pyplot as plt


importances = mod3.feature_importances_

# ממיינים את המשתנים לפי החשיבות
indices = np.argsort(importances)[::-1]

# מציגים את המשתנים לפי סדר החשיבות
feature_names = X.columns  # אם X הוא DataFrame
for f in range(X.shape[1]):
    print(f"{feature_names[indices[f]]}: {importances[indices[f]]}")

# יצירת גרף בר עם חשיבות המשתנים
plt.figure(figsize=(10, 6))
plt.barh(feature_names[indices], importances[indices])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance for Random Forest Model')
plt.show()
# Out:
# Bedrooms_encoded: 0.2629058231707379
# Room Type_encoded: 0.0921778488953477
# Bathrooms_encoded: 0.09175928746922118
# Accomodates: 0.07627334284095469
# Host_tenure: 0.0587300103685284
# Guests Included: 0.05590309429229313
# Listing ID: 0.048223714287661486
# review_mnt: 0.04541305196122918
# Reviews: 0.033074926900327185
# Neighborhood Group_encoded: 0.026710538749573833
# Overall Rating: 0.026281674079677863
# Property Type_encoded: 0.02559993745060068
# Min Nights: 0.02541954585633118
# Sentiment_All: 0.02165058475744457
# Total Bookings: 0.0147867890757299
# Beds_encoded: 0.014585157447899656
# Host Response Rate: 0.011958400695616616
# Sentiment_Pos_per: 0.010340963463452129
# Location Rating_encoded: 0.010277120176307927
# Sentiment_Nut_per: 0.010259955323686136
# Value Rating_encoded: 0.007892730405464054
# Is Superhost: 0.007624946375115604
# Host Response Time_encoded: 0.007405893741072561
# Cleanliness Rating_encoded: 0.007200137971060953
# ...
